# %%
import skimage.io as io
import skimage as ski

# %%
c = io.imread('images/moon.tif')
cd1 = c.astype(float)
cd2 = ski.util.img_as_float(c)

# %%
c.dtype, cd1.dtype, cd2.dtype
# Out:
# (dtype('uint8'), dtype('float64'), dtype('float64'))

# %%
io.imshow(c)

# %%
io.imshow(cd1)
# Out:
# c:\users\roman\venv\dip\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:150: UserWarning: Float image out of standard range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)

# %%
io.imshow(cd2)

# %%
c.min(), c.max()
# Out:
# (0, 253)

# %%
cd1.min(), cd1.max()
# Out:
# (0.0, 253.0)

# %%
cd2.min(), cd2.max()
# Out:
# (0.0, 0.9921568627450981)

# %%
io.imshow(cd1/2,vmin=0,vmax=255)

# %%
io.imshow(cd1*2,vmin=0,vmax=255)

# %%
import numpy as np
a = np.array([[0,80],[160,240]]).astype(np.uint8)
a
# Out:
# array([[  0,  80],
#        [160, 240]], dtype=uint8)

# %%
(a-10)*2 # modul0 256
# Out:
# array([[236, 140],
#        [ 44, 204]], dtype=uint8)

# %%
cl = c > 129
cl.dtype
# Out:
# dtype('bool')

# %%
clu = ski.util.img_as_ubyte(cl)
io.imshow(clu)

# %%
clu = np.uint8(cl*255)
io.imshow(clu)

# %%
clu = ski.util.img_as_float(cl)
io.imshow(clu)
